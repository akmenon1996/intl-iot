# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as mpt

# %%
blink_camera_power_1 = pd.read_csv(r'/home/amenon/Desktop/GIT_Projects/intl-abhijit/intl-iot/iot-data/us/blink-camera/power/2019-04-25_19:21:41.165s.pcap.csv')

# %%
blink_camera_power_1
# Out:
#     frame.number                           frame.time            eth.src  \
# 0              1  Apr 25, 2019 19:23:18.719129000 EDT  f4:b8:5e:31:73:db
# 1              2  Apr 25, 2019 19:23:18.719224000 EDT  00:21:cc:4d:ce:8c
# 2              3  Apr 25, 2019 19:23:18.759988000 EDT  f4:b8:5e:31:73:db
# 3              4  Apr 25, 2019 19:23:19.360537000 EDT  f4:b8:5e:31:73:db
# 4              5  Apr 25, 2019 19:23:23.265358000 EDT  f4:b8:5e:31:73:db
# 5              6  Apr 25, 2019 19:23:26.676609000 EDT  f4:b8:5e:31:73:db
# 6              7  Apr 25, 2019 19:23:26.676715000 EDT  22:ef:03:1a:97:b9
# 7              8  Apr 25, 2019 19:23:26.688407000 EDT  f4:b8:5e:31:73:db
# 8              9  Apr 25, 2019 19:23:26.786218000 EDT  22:ef:03:1a:97:b9
# 9             10  Apr 25, 2019 19:23:26.790796000 EDT  f4:b8:5e:31:73:db
# 10            11  Apr 25, 2019 19:23:26.790844000 EDT  22:ef:03:1a:97:b9
# 11            12  Apr 25, 2019 19:23:26.917648000 EDT  22:ef:03:1a:97:b9
# ...
